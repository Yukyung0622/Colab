# %% [markdown]
# <a href="https://colab.research.google.com/github/Yukyung0622/Colab/blob/master/PythonDataWorkspace/Pandas/06%EB%8D%B0%EC%9D%B4%ED%84%B0_%EC%84%A0%ED%83%9D(%EA%B8%B0%EB%B3%B8).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#6.데이터 선택(기본)

import pandas as pd


data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

df = pd.DataFrame(data, index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name='지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
#Column 선택(label)
df['이름']
# Out:
# 지원번호
# 1번    채치수
# 2번    정대만
# 3번    송태섭
# 4번    서태웅
# 5번    강백호
# 6번    변덕규
# 7번    황태산
# 8번    윤대협
# Name: 이름, dtype: object

# %%
df['키']
# Out:
# 지원번호
# 1번    197
# 2번    184
# 3번    168
# 4번    187
# 5번    188
# 6번    202
# 7번    188
# 8번    190
# Name: 키, dtype: int64

# %%
df[['이름', '키']]
# Out:
#        이름    키
# 지원번호
# 1번    채치수  197
# 2번    정대만  184
# 3번    송태섭  168
# 4번    서태웅  187
# 5번    강백호  188
# 6번    변덕규  202
# 7번    황태산  188
# 8번    윤대협  190

# %%
##Column 선택 (정수 index)
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df.columns[0]
# Out:
# '이름'

# %%
df.columns[2]
# Out:
# '키'

# %%
df[df.columns[0]] #df['이름']과 동일한 동작
# Out:
# 지원번호
# 1번    채치수
# 2번    정대만
# 3번    송태섭
# 4번    서태웅
# 5번    강백호
# 6번    변덕규
# 7번    황태산
# 8번    윤대협
# Name: 이름, dtype: object

# %%
df[df.columns[-1]] #맨끝에 있는 값을 불러옴
# Out:
# 지원번호
# 1번        Python
# 2번          Java
# 3번    Javascript
# 4번
# 5번
# 6번             C
# 7번        PYTHON
# 8번            C#
# Name: SW특기, dtype: object

# %%
#슬라이싱
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    채치수  북산고  197   90   85  100  95  85      Python
# 2번    정대만  북산고  184   40   35   50  55  25        Java
# 3번    송태섭  북산고  168   80   75   70  80  75  Javascript
# 4번    서태웅  북산고  187   40   60   70  75  80
# 5번    강백호  북산고  188   15   20   10  35  10
# 6번    변덕규  능남고  202   80  100   95  85  80           C
# 7번    황태산  능남고  188   55   65   45  40  35      PYTHON
# 8번    윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['영어'][0:5] #0~4까지 영어어 점수 데이터를 가져옴
# Out:
# 지원번호
# 1번    85
# 2번    35
# 3번    75
# 4번    60
# 5번    20
# Name: 영어, dtype: int64

# %%
df[['이름', '키']][:3] #처음 3명의 이름, 키 정보를 가져옴
# Out:
#        이름    키
# 지원번호
# 1번    채치수  197
# 2번    정대만  184
# 3번    송태섭  168

# %%
df[3:]
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# 4번    서태웅  북산고  187   40   60  70  75  80
# 5번    강백호  북산고  188   15   20  10  35  10
# 6번    변덕규  능남고  202   80  100  95  85  80       C
# 7번    황태산  능남고  188   55   65  45  40  35  PYTHON
# 8번    윤대협  능남고  190  100   85  90  95  95      C#
