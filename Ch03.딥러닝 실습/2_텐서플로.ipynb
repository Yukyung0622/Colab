# %% [markdown]
# <a href="https://colab.research.google.com/github/Yukyung0622/Colab/blob/master/Ch03.%EB%94%A5%EB%9F%AC%EB%8B%9D%20%EC%8B%A4%EC%8A%B5/2_%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
날짜 : 2022/05/09
이름 : 김유경
내용 : 텐서플로 XOR 실습하기
"""
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import mse
tf.__version__
# Out:
# '2.8.0'

# %%
#데이터
data = np.array([[0,0], [0,1], [1,0], [1,1]])
label = np.array([[0], [1], [1], [0]])

# %%
#모델 설계
model = Sequential()
model.add(Dense(units=2, input_shape=(2,), activation='sigmoid'))
model.add(Dense(units=1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 2)                 6
#
#  dense_11 (Dense)            (None, 1)                 3
#
# ...
# Total params: 9
# Trainable params: 9
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델 설정
model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.1), loss='mse', metrics=['acc'])

# %%
#학습하기
model.fit(data, label, epochs=2000, batch_size=1)
# Out:
# Epoch 1/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2540 - acc: 0.2500
# Epoch 2/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2540 - acc: 0.2500
# Epoch 3/2000
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2539 - acc: 0.5000
# Epoch 4/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2540 - acc: 0.2500
# Epoch 5/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2540 - acc: 0.2500
# Epoch 6/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2540 - acc: 0.5000
# Epoch 7/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2540 - acc: 0.5000
# Epoch 8/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2539 - acc: 0.2500
# Epoch 9/2000
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2539 - acc: 0.2500
# Epoch 10/2000
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2539 - acc: 0.5000
# Epoch 11/2000
# ...

# %%
#테스트
test_data = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
result = model.predict(test_data)
result
# Out:
# array([[0.13623211],
#        [0.8054473 ],
#        [0.8051933 ],
#        [0.2784086 ]], dtype=float32)
